# %%
import pandas as pd
from mega import mega_df

# %%
all_seasons = mega_df.copy()
all_seasons
# Out:
#       Gm#              Date   Tm H/A  Opp      W/L        R       RA  \
# 0       1      Monday Apr 1  COL   @  MIL     L-wo        4        5
# 1       2     Tuesday Apr 2  COL   @  MIL        W        8        4
# 2       3   Wednesday Apr 3  COL   @  MIL        W        7        3
# 3       4      Friday Apr 5  COL   H  SDP        W        5        2
# 4       5    Saturday Apr 6  COL   H  SDP        W        6        3
# ...   ...               ...  ...  ..  ...      ...      ...      ...
# 1837  158  Wednesday Sep 25  COL   H  STL  8:40 pm  8:40 pm  8:40 pm
# 1838  159   Thursday Sep 26  COL   H  STL  3:10 pm  3:10 pm  3:10 pm
# 1839  160     Friday Sep 27  COL   H  LAD  8:10 pm  8:10 pm  8:10 pm
# 1840  161   Saturday Sep 28  COL   H  LAD  8:10 pm  8:10 pm  8:10 pm
# 1841  162     Sunday Sep 29  COL   H  LAD  3:10 pm  3:10 pm  3:10 pm
#
#                             Inn                        W-L  ...  \
# 0                          10.0                        0-1  ...
# 1                           NaN                        1-1  ...
# 2                           NaN                        2-1  ...
# 3                           NaN                        3-1  ...
# 4                           NaN                        4-1  ...
# ...                         ...                        ...  ...
# 1837  Game Preview and Matchups  Game Preview and Matchups  ...
# 1838  Game Preview and Matchups  Game Preview and Matchups  ...
# 1839  Game Preview and Matchups  Game Preview and Matchups  ...
# 1840  Game Preview and Matchups  Game Preview and Matchups  ...
# 1841  Game Preview and Matchups  Game Preview and Matchups  ...
#
#                             Win                       Loss  \
# 0                     Henderson                   Ottavino
# 1                      Escalona                   Gonzalez
# 2                       Nicasio                    Peralta
# 3                       Francis                    Marquis
# 4                       Garland                       Ross
# ...                         ...                        ...
# 1837  Game Preview and Matchups  Game Preview and Matchups
# 1838  Game Preview and Matchups  Game Preview and Matchups
# 1839  Game Preview and Matchups  Game Preview and Matchups
# 1840  Game Preview and Matchups  Game Preview and Matchups
# 1841  Game Preview and Matchups  Game Preview and Matchups
#
#                            Save                       Time  \
# 0                           NaN                       3:13
# 1                    Betancourt                       3:22
# 2                           NaN                       3:31
# 3                    Betancourt                       2:45
# 4                    Betancourt                       2:54
# ...                         ...                        ...
# 1837  Game Preview and Matchups  Game Preview and Matchups
# 1838  Game Preview and Matchups  Game Preview and Matchups
# 1839  Game Preview and Matchups  Game Preview and Matchups
# 1840  Game Preview and Matchups  Game Preview and Matchups
# 1841  Game Preview and Matchups  Game Preview and Matchups
#
#                             D/N                 Attendance   cLI Streak  \
# 0                             D                      45781  0.93      -
# 1                             N                      24753  0.93      +
# 2                             N                      25766  0.95     ++
# 3                             D                      49077  1.08    +++
# 4                             N                      31133  1.12   ++++
# ...                         ...                        ...   ...    ...
# 1837  Game Preview and Matchups  Game Preview and Matchups   NaN    NaN
# 1838  Game Preview and Matchups  Game Preview and Matchups   NaN    NaN
# 1839  Game Preview and Matchups  Game Preview and Matchups   NaN    NaN
# 1840  Game Preview and Matchups  Game Preview and Matchups   NaN    NaN
# 1841  Game Preview and Matchups  Game Preview and Matchups   NaN    NaN
#
#       Orig. Scheduled  Year
# 0                 NaN  2013
# 1                 NaN  2013
# 2                 NaN  2013
# 3                 NaN  2013
# 4                 NaN  2013
# ...               ...   ...
# 1837              NaN  2024
# 1838              NaN  2024
# 1839              NaN  2024
# 1840              NaN  2024
# 1841              NaN  2024
#
# [1842 rows x 22 columns]

# %% [markdown]
# take out 29 rows of unplayed games for training data
# look for more statistical feature data, who played each game
# remove all data leakage rows (most)
#
# https://www.fangraphs.com/teams/rockies/player-usage/defensive-lineup
#
# python resource:
# https://github.com/jldbc/pybaseball

# %%
pip install pybaseball
# Out:
# Collecting pybaseballNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (2.1.4)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (4.12.2)
# Requirement already satisfied: requests>=2.18.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (2.32.2)
# Requirement already satisfied: lxml>=4.2.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (4.9.3)
# Requirement already satisfied: pyarrow>=1.0.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (14.0.2)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (1.11.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (3.8.0)
# Requirement already satisfied: tqdm>=4.50.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (4.65.0)
# Requirement already satisfied: attrs>=20.3.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pybaseball) (23.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\elcoo\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcoo\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pandas>=1.0.3->pybaseball) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pandas>=1.0.3->pybaseball) (2023.3)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (1.5.0)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\elcoo\anaconda3\lib\site-packages (from pygithub>=1.51->pybaseball) (2.0.7)
# Collecting Deprecated (from pygithub>=1.51->pybaseball)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elcoo\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elcoo\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elcoo\anaconda3\lib\site-packages (from requests>=2.18.1->pybaseball) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\elcoo\anaconda3\lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)
# Requirement already satisfied: cryptography>=3.3.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (42.0.2)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\elcoo\anaconda3\lib\site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\elcoo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\elcoo\anaconda3\lib\site-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.14.1)
# Requirement already satisfied: pycparser in c:\users\elcoo\anaconda3\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.21)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ---------------------------------------- 0.0/426.1 kB ? eta -:--:--
#    -------- ------------------------------- 92.2/426.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 426.1/426.1 kB 5.3 MB/s eta 0:00:00
# Downloading PyGithub-2.4.0-py3-none-any.whl (362 kB)
#    ---------------------------------------- 0.0/362.6 kB ? eta -:--:--
#    --------------------------------------- 362.6/362.6 kB 11.4 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: Deprecated, pygithub, pybaseball
# Successfully installed Deprecated-1.2.14 pybaseball-2.2.7 pygithub-2.4.0

# %%
from pybaseball import statcast

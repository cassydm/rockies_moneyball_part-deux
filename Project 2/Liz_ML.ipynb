# %%
import pandas as pd
from mega import mega_df_cleaned
from functions import team_batting_avg
from pybaseball import statcast

# %%
all_seasons = mega_df_cleaned.copy()
all_seasons.head(4)
# Out:
#    Gm#             Date   Tm  ...  Year              Full_Date Formatted_Date
# 0    1     Monday Apr 1  COL  ...  2013     Monday Apr 1, 2013     2013-04-01
# 1    2    Tuesday Apr 2  COL  ...  2013    Tuesday Apr 2, 2013     2013-04-02
# 2    3  Wednesday Apr 3  COL  ...  2013  Wednesday Apr 3, 2013     2013-04-03
# 3    4     Friday Apr 5  COL  ...  2013     Friday Apr 5, 2013     2013-04-05
#
# [4 rows x 24 columns]

# %%
all_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1780 entries, 0 to 1841
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gm#              1780 non-null   int64
#  1   Date             1780 non-null   object
#  2   Tm               1780 non-null   object
#  3   H/A              1780 non-null   object
#  4   Opp              1780 non-null   object
#  5   W/L              1780 non-null   object
#  6   R                1780 non-null   object
#  7   RA               1780 non-null   object
#  8   Inn              156 non-null    object
#  9   W-L              1780 non-null   object
#  10  Rank             1780 non-null   object
#  11  GB               1780 non-null   object
#  12  Win              1780 non-null   object
#  13  Loss             1780 non-null   object
#  14  Save             879 non-null    object
#  15  Time             1780 non-null   object
#  16  D/N              1780 non-null   object
# ...

# %%
filtered_df = all_seasons[all_seasons['Formatted_Date'] == 'Invalid date format']

# %%
df_cleaned = all_seasons[all_seasons['Formatted_Date'] != 'Invalid date format']

# %%
df_cleaned['COL_ba'] = df_cleaned.apply(lambda row: team_batting_avg(row['Tm'], row['Formatted_Date']), axis=1)
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 13.84it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 15.28it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 17.14it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.66it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.12it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.61it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.83it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.28it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 13.64it/s]
# ...

# %%
df_cleaned.head(12)
# Out:
#     Gm#              Date   Tm  ...               Full_Date Formatted_Date    COL_ba
# 0     1      Monday Apr 1  COL  ...      Monday Apr 1, 2013     2013-04-01  0.258065
# 1     2     Tuesday Apr 2  COL  ...     Tuesday Apr 2, 2013     2013-04-02  0.281250
# 2     3   Wednesday Apr 3  COL  ...   Wednesday Apr 3, 2013     2013-04-03  0.264706
# 3     4      Friday Apr 5  COL  ...      Friday Apr 5, 2013     2013-04-05  0.212121
# 4     5    Saturday Apr 6  COL  ...    Saturday Apr 6, 2013     2013-04-06  0.242424
# 5     6      Sunday Apr 7  COL  ...      Sunday Apr 7, 2013     2013-04-07  0.272727
# 6     7      Monday Apr 8  COL  ...      Monday Apr 8, 2013     2013-04-08  0.275862
# 7     8     Tuesday Apr 9  COL  ...     Tuesday Apr 9, 2013     2013-04-09  0.451613
# 8     9  Wednesday Apr 10  COL  ...  Wednesday Apr 10, 2013     2013-04-10  0.444444
# 9    10     Friday Apr 12  COL  ...     Friday Apr 12, 2013     2013-04-12  0.272727
# ...

# %%
# export COL_ba column to separate csv file
COL_ba_column = df_cleaned["COL_ba"]
COL_ba_column.to_csv("progress_dataframes/COL_ba_column.csv", header=True)

# %%
from functions import team_obp

df_cleaned_obp = df_cleaned.copy()
df_cleaned_obp
# Out:
#       Gm#              Date   Tm  ...  Year               Full_Date Formatted_Date
# 0       1      Monday Apr 1  COL  ...  2013      Monday Apr 1, 2013     2013-04-01
# 1       2     Tuesday Apr 2  COL  ...  2013     Tuesday Apr 2, 2013     2013-04-02
# 2       3   Wednesday Apr 3  COL  ...  2013   Wednesday Apr 3, 2013     2013-04-03
# 3       4      Friday Apr 5  COL  ...  2013      Friday Apr 5, 2013     2013-04-05
# 4       5    Saturday Apr 6  COL  ...  2013    Saturday Apr 6, 2013     2013-04-06
# ...   ...               ...  ...  ...   ...                     ...            ...
# 1837  158  Wednesday Sep 25  COL  ...  2024  Wednesday Sep 25, 2024     2024-09-25
# 1838  159   Thursday Sep 26  COL  ...  2024   Thursday Sep 26, 2024     2024-09-26
# 1839  160     Friday Sep 27  COL  ...  2024     Friday Sep 27, 2024     2024-09-27
# 1840  161   Saturday Sep 28  COL  ...  2024   Saturday Sep 28, 2024     2024-09-28
# ...

# %%
#apply obp function to the mega dataframe
df_cleaned_obp['COL_obp'] = df_cleaned_obp.apply(lambda row: team_obp(row['Tm'], row['Formatted_Date']), axis=1)

# %%
df_cleaned_obp.head()
# Out:
#    Gm#             Date   Tm  ...              Full_Date Formatted_Date   COL_obp
# 0    1     Monday Apr 1  COL  ...     Monday Apr 1, 2013     2013-04-01  0.351351
# 1    2    Tuesday Apr 2  COL  ...    Tuesday Apr 2, 2013     2013-04-02  0.342857
# 2    3  Wednesday Apr 3  COL  ...  Wednesday Apr 3, 2013     2013-04-03  0.305556
# 3    4     Friday Apr 5  COL  ...     Friday Apr 5, 2013     2013-04-05  0.235294
# 4    5   Saturday Apr 6  COL  ...   Saturday Apr 6, 2013     2013-04-06  0.305556
#
# [5 rows x 25 columns]

# %%
# export COL_obp column to separate csv file
COL_obp_column = df_cleaned_obp["COL_obp"]
COL_obp_column.to_csv("progress_dataframes/COL_obp_column.csv", header=True)

# %%
from functions import team_stats

df_cleaned_hits = df_cleaned_obp.copy()
df_cleaned_hits.head()
# Out:
#    Gm#             Date   Tm  ...              Full_Date Formatted_Date   COL_obp
# 0    1     Monday Apr 1  COL  ...     Monday Apr 1, 2013     2013-04-01  0.351351
# 1    2    Tuesday Apr 2  COL  ...    Tuesday Apr 2, 2013     2013-04-02  0.342857
# 2    3  Wednesday Apr 3  COL  ...  Wednesday Apr 3, 2013     2013-04-03  0.305556
# 3    4     Friday Apr 5  COL  ...     Friday Apr 5, 2013     2013-04-05  0.235294
# 4    5   Saturday Apr 6  COL  ...   Saturday Apr 6, 2013     2013-04-06  0.305556
#
# [5 rows x 25 columns]

# %%
#apply obp function to the mega dataframe
df_cleaned_hits['COL_hits'] = df_cleaned_hits.apply(lambda row: team_stats(row['Tm'], row['Formatted_Date'], "hits"), axis=1)

# %%
df_cleaned_hits.head()
# Out:
#    Gm#             Date   Tm  ... Formatted_Date   COL_obp COL_hits
# 0    1     Monday Apr 1  COL  ...     2013-04-01  0.351351        8
# 1    2    Tuesday Apr 2  COL  ...     2013-04-02  0.342857        9
# 2    3  Wednesday Apr 3  COL  ...     2013-04-03  0.305556        9
# 3    4     Friday Apr 5  COL  ...     2013-04-05  0.235294        7
# 4    5   Saturday Apr 6  COL  ...     2013-04-06  0.305556        8
#
# [5 rows x 26 columns]

# %%
# export COL_hits column to separate csv file
COL_hits_column = df_cleaned_hits["COL_hits"]
COL_hits_column.to_csv("progress_dataframes/COL_hits_column.csv", header=True)

# %%
df_cleaned_walks = df_cleaned_hits.copy()
df_cleaned_walks.head()
# Out:
#    Gm#             Date   Tm  ... Formatted_Date   COL_obp COL_hits
# 0    1     Monday Apr 1  COL  ...     2013-04-01  0.351351        8
# 1    2    Tuesday Apr 2  COL  ...     2013-04-02  0.342857        9
# 2    3  Wednesday Apr 3  COL  ...     2013-04-03  0.305556        9
# 3    4     Friday Apr 5  COL  ...     2013-04-05  0.235294        7
# 4    5   Saturday Apr 6  COL  ...     2013-04-06  0.305556        8
#
# [5 rows x 26 columns]

# %%
#apply obp function to the mega dataframe
df_cleaned_walks['COL_walks'] = df_cleaned_walks.apply(lambda row: team_stats(row['Tm'], row['Formatted_Date'], "walks"), axis=1)

# %%
df_cleaned_walks.head()
# Out:
#    Gm#             Date   Tm H/A  ... Formatted_Date   COL_obp COL_hits COL_walks
# 0    1     Monday Apr 1  COL   @  ...     2013-04-01  0.351351        8         4
# 1    2    Tuesday Apr 2  COL   @  ...     2013-04-02  0.342857        9         3
# 2    3  Wednesday Apr 3  COL   @  ...     2013-04-03  0.305556        9         2
# 3    4     Friday Apr 5  COL   H  ...     2013-04-05  0.235294        7         1
# 4    5   Saturday Apr 6  COL   H  ...     2013-04-06  0.305556        8         3
#
# [5 rows x 27 columns]

# %%
# export COL_walks column to separate csv file
COL_walks_column = df_cleaned_walks["COL_walks"]
COL_walks_column.to_csv("progress_dataframes/COL_walks_column.csv", header=True)

# %%
df_cleaned_atbats = df_cleaned_walks.copy()
df_cleaned_atbats.head()
# Out:
#    Gm#             Date   Tm H/A  ... Formatted_Date   COL_obp COL_hits COL_walks
# 0    1     Monday Apr 1  COL   @  ...     2013-04-01  0.351351        8         4
# 1    2    Tuesday Apr 2  COL   @  ...     2013-04-02  0.342857        9         3
# 2    3  Wednesday Apr 3  COL   @  ...     2013-04-03  0.305556        9         2
# 3    4     Friday Apr 5  COL   H  ...     2013-04-05  0.235294        7         1
# 4    5   Saturday Apr 6  COL   H  ...     2013-04-06  0.305556        8         3
#
# [5 rows x 27 columns]

# %%
#apply stats function to the mega dataframe
df_cleaned_atbats['COL_at_bats'] = df_cleaned_atbats.apply(lambda row: team_stats(row['Tm'], row['Formatted_Date'], "at bats"), axis=1)

# %%
df_cleaned_atbats.head()
# Out:
#    Gm#             Date   Tm H/A  ...   COL_obp COL_hits COL_walks COL_at_bats
# 0    1     Monday Apr 1  COL   @  ...  0.351351        8         4          31
# 1    2    Tuesday Apr 2  COL   @  ...  0.342857        9         3          32
# 2    3  Wednesday Apr 3  COL   @  ...  0.305556        9         2          34
# 3    4     Friday Apr 5  COL   H  ...  0.235294        7         1          33
# 4    5   Saturday Apr 6  COL   H  ...  0.305556        8         3          33
#
# [5 rows x 28 columns]

# %%
# export COL_atbats column to separate csv file
COL_atbats_column = df_cleaned_atbats["COL_at_bats"]
COL_atbats_column.to_csv("progress_dataframes/COL_atbats_column.csv", header=True)

# %%
df_cleaned_hr = df_cleaned_atbats.copy()
df_cleaned_hr.head()
# Out:
#    Gm#             Date   Tm H/A  ...   COL_obp COL_hits COL_walks COL_at_bats
# 0    1     Monday Apr 1  COL   @  ...  0.351351        8         4          31
# 1    2    Tuesday Apr 2  COL   @  ...  0.342857        9         3          32
# 2    3  Wednesday Apr 3  COL   @  ...  0.305556        9         2          34
# 3    4     Friday Apr 5  COL   H  ...  0.235294        7         1          33
# 4    5   Saturday Apr 6  COL   H  ...  0.305556        8         3          33
#
# [5 rows x 28 columns]

# %%
#apply stats function to the mega dataframe
df_cleaned_hr['COL_hr'] = df_cleaned_hr.apply(lambda row: team_stats(row['Tm'], row['Formatted_Date'], "home runs"), axis=1)
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 13.16it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 17.52it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 14.63it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 11.97it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.12it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 17.16it/s]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:00<00:00, 16.82it/s]
# ...

# %%
df_cleaned_hr.head()
# Out:
#    Gm#             Date   Tm H/A  ... COL_hits COL_walks COL_at_bats COL_hr
# 0    1     Monday Apr 1  COL   @  ...        8         4          31      1
# 1    2    Tuesday Apr 2  COL   @  ...        9         3          32      1
# 2    3  Wednesday Apr 3  COL   @  ...        9         2          34      1
# 3    4     Friday Apr 5  COL   H  ...        7         1          33      0
# 4    5   Saturday Apr 6  COL   H  ...        8         3          33      0
#
# [5 rows x 29 columns]

# %%
# export COL_hr column to separate csv file
COL_hr_column = df_cleaned_hr["COL_hr"]
COL_hr_column.to_csv("progress_dataframes/COL_hr_column.csv", header=True)

# %%
df_cleaned_kk = df_cleaned_hr.copy()
df_cleaned_kk.head()
# Out:
#    Gm#             Date   Tm H/A  ... COL_hits COL_walks COL_at_bats COL_hr
# 0    1     Monday Apr 1  COL   @  ...        8         4          31      1
# 1    2    Tuesday Apr 2  COL   @  ...        9         3          32      1
# 2    3  Wednesday Apr 3  COL   @  ...        9         2          34      1
# 3    4     Friday Apr 5  COL   H  ...        7         1          33      0
# 4    5   Saturday Apr 6  COL   H  ...        8         3          33      0
#
# [5 rows x 29 columns]

# %%
#apply stats function to the mega dataframe
df_cleaned_kk['COL_kk'] = df_cleaned_kk.apply(lambda row: team_stats(row['Tm'], row['Formatted_Date'], "strikeouts"), axis=1)
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]
# This is a large query, it may take a moment to complete
# 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# ...

# %%
df_cleaned_kk.head()
# Out:
#    Gm#             Date   Tm H/A  ... COL_walks COL_at_bats COL_hr COL_kk
# 0    1     Monday Apr 1  COL   @  ...         4          31      1      8
# 1    2    Tuesday Apr 2  COL   @  ...         3          32      1      5
# 2    3  Wednesday Apr 3  COL   @  ...         2          34      1      5
# 3    4     Friday Apr 5  COL   H  ...         1          33      0      8
# 4    5   Saturday Apr 6  COL   H  ...         3          33      0      4
#
# [5 rows x 30 columns]

# %%
# export COL_hr column to separate csv file
COL_kk_column = df_cleaned_kk["COL_kk"]
COL_kk_column.to_csv("progress_dataframes/COL_kk_column.csv", header=True)

# %% [markdown]
# # code snippet

# %%
# create copy dataframe
df_cleaned_kk = df_cleaned_hr.copy()
df_cleaned_kk.head()

#apply stats function to the mega dataframe
df_cleaned_kk['COL_kk'] = df_cleaned_kk.apply(lambda row: team_stats(row['Opp'], row['Formatted_Date'], "strikeouts"), axis=1)  

# check 
df_cleaned_kk.head()

# export COL_hr column to separate csv file
COL_kk_column = df_cleaned_kk["COL_kk"]
COL_kk_column.to_csv("progress_dataframes/COL_kk_column.csv", header=True)

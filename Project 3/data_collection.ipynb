# %% [markdown]
# # Data Collection from PyBaseball Library

# %%
# import dependencies/libraries

from pybaseball import statcast_pitcher, playerid_lookup
import pandas as pd

# %%
# dictionary for each starting pitcher in the 2024 Rockies roster

pitcher_dictionary = {"Kyle Freeland": {"name": ["freeland", 'kyle'], "start_date" : "2017-01-01", "end_date":"2024-10-21"},
                       "Germán Márquez": {"name": ['marquez', 'german'],"start_date" : "2016-01-01", "end_date":"2024-10-21"},
                       "Antonio Senzatela": {"name": ['senzatela', 'antonio'], "start_date" : "2017-01-01", "end_date":"2024-10-21"},
                       "Ryan Feltner": {"name": ['feltner', 'ryan'], "start_date" : "2021-01-01", "end_date":"2024-10-21"},
                       "Chris Flexen": {"name": ['flexen', 'chris'], "start_date" : "2017-01-01", "end_date":"2024-10-21"}}

# %%
# define function to lookup each pitcher listed in "pitcher_database" in the pybaseball library, and return all play-by-play data for all games in each player's MLB career history.

def get_pitcher_data(pitcher_dictionary):
    all_pitcher_data = {}

    for pitcher_name, info in pitcher_dictionary.items():
        print(f"Processing data for {pitcher_name}...")
        
        # Lookup player ID
        last_name, first_name = info['name']
        pitcher_lookup = playerid_lookup(last_name, first_name)
        
        # Defensive coding in case the ID does not exist
        if pitcher_lookup.empty:
            print(f"Could not find player ID for {pitcher_name}. Skipping...")
            continue
        
        pitcher_id = pitcher_lookup['key_mlbam'].iloc[0]
        
        # Get play-by-play data for pitcher ID that does exist
        start_date = info['start_date']
        end_date = info['end_date']
        
        try:
            data = statcast_pitcher(start_date, end_date, pitcher_id)
            all_pitcher_data[pitcher_name] = data
            print(f"Successfully retrieved data for {pitcher_name}")
        except Exception as e:
            print(f"Error retrieving data for {pitcher_name}: {str(e)}")
    
    return all_pitcher_data

pitcher_data = get_pitcher_data(pitcher_dictionary)

# Print summary of retrieved data
for pitcher, data in pitcher_data.items():
    print(f"{pitcher}: {len(data)} rows of data")
# Out:
# Processing data for Kyle Freeland...
# Gathering player lookup table. This may take a moment.
# Gathering Player Data
# Successfully retrieved data for Kyle Freeland
# Processing data for Germán Márquez...
# Gathering Player Data
# c:\Users\elcoo\anaconda3\Lib\site-packages\pybaseball\utils.py:295: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(io.StringIO(data.text))
# Successfully retrieved data for Germán Márquez
# Processing data for Antonio Senzatela...
# Gathering Player Data
# Successfully retrieved data for Antonio Senzatela
# Processing data for Ryan Feltner...
# Gathering Player Data
# Successfully retrieved data for Ryan Feltner
# Processing data for Chris Flexen...
# Gathering Player Data
# Successfully retrieved data for Chris Flexen
# Kyle Freeland: 19163 rows of data
# Germán Márquez: 17257 rows of data
# Antonio Senzatela: 12258 rows of data
# Ryan Feltner: 5717 rows of data
# Chris Flexen: 11420 rows of data

# %%
# convert "get_pitcher_data" function's output from dictionary to dataframes

## change play-by-play data keys/values into dictionary for each player
player_dict_dataframes = {player: pd.DataFrame(data) for player, data in pitcher_data.items()}

## convert each player key and values to separate dataframe
freeland_df = player_dict_dataframes['Kyle Freeland']
marquez_df = player_dict_dataframes['Germán Márquez']
senzatela_df = player_dict_dataframes['Antonio Senzatela']
feltner_df = player_dict_dataframes['Ryan Feltner']
flexen_df = player_dict_dataframes['Chris Flexen']

# %%
# test exporting a dataframe to excel for quick, easy viewing
# freeland_df.to_excel("../excel/test_data.xlsx")

# %% [markdown]
# # Extrapolate new data from PyBaseball data

# %%
# define a function to:
## 1. sort the dataframes
## 2. create a pitch count column
## 3. create a trailing pitch column

def add_data_df(df):
    df_sort = df.sort_values(by=['game_date', 'at_bat_number','pitch_number'])
    df_sort['pitch_count'] = df_sort.groupby("game_date").cumcount()+1
    df_sort['trailing_pitch'] = df_sort.groupby("batter")['pitch_type'].shift(1)
    return df_sort

# %%
# sort Freeland's dataframe and add columns
freeland_df_sorted = add_data_df(freeland_df)
freeland_df_sorted.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 14654         FF  2017-02-28           93.5           3.20           5.68
# 14653         FF  2017-02-28           93.5           3.08           5.96
# 14652         SL  2017-02-28           92.0           3.27           5.66
# 14651         FF  2017-02-28           95.1           3.25           5.64
# 14650         SL  2017-02-28           87.8           3.21           5.76
#
#           player_name  batter  pitcher     events      description  ...  \
# 14654  Freeland, Kyle  444843   607536        NaN             ball  ...
# 14653  Freeland, Kyle  444843   607536        NaN             foul  ...
# 14652  Freeland, Kyle  444843   607536        NaN             foul  ...
# 14651  Freeland, Kyle  444843   607536        NaN             foul  ...
# 14650  Freeland, Kyle  444843   607536  strikeout  swinging_strike  ...
#
#        post_fld_score  if_fielding_alignment  of_fielding_alignment  \
# 14654               0               Standard               Standard
# 14653               0               Standard               Standard
# 14652               0               Standard               Standard
# 14651               0               Standard               Standard
# 14650               0               Standard               Standard
#
#        spin_axis  delta_home_win_exp delta_run_exp bat_speed swing_length  \
# 14654      148.0               0.000           NaN       NaN          NaN
# 14653      169.0               0.000           NaN       NaN          NaN
# 14652      176.0               0.000           NaN       NaN          NaN
# 14651      141.0               0.000           NaN       NaN          NaN
# 14650      193.0               0.022           NaN       NaN          NaN
#
#       pitch_count trailing_pitch
# 14654           1            NaN
# 14653           2             FF
# 14652           3             FF
# 14651           4             SL
# 14650           5             FF
#
# [5 rows x 96 columns]

# %%
# sort Marquez's dataframe and add columns
marquez_df_sorted = add_data_df(marquez_df)
marquez_df_sorted.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 13738         FF  2016-03-13           95.2          -2.07           5.93
# 13737         FF  2016-03-13           95.6          -2.14           6.10
# 13736         FF  2016-03-13           95.4          -2.08           5.96
# 13735         FF  2016-03-13           96.0          -2.06           6.07
# 13734        NaN  2016-03-13            NaN            NaN            NaN
#
#            player_name  batter  pitcher     events    description  ...  \
# 13738  Márquez, Germán  518794   608566        NaN           foul  ...
# 13737  Márquez, Germán  518794   608566        NaN           ball  ...
# 13736  Márquez, Germán  518794   608566        NaN           ball  ...
# 13735  Márquez, Germán  518794   608566        NaN           ball  ...
# 13734  Márquez, Germán  518794   608566  field_out  hit_into_play  ...
#
#        post_fld_score  if_fielding_alignment  of_fielding_alignment  \
# 13738               0               Standard               Standard
# 13737               0               Standard               Standard
# 13736               0               Standard               Standard
# 13735               0               Standard               Standard
# 13734               0                    NaN                    NaN
#
#        spin_axis  delta_home_win_exp delta_run_exp bat_speed swing_length  \
# 13738      206.0               0.000           NaN       NaN          NaN
# 13737      208.0               0.000           NaN       NaN          NaN
# 13736      200.0               0.000           NaN       NaN          NaN
# 13735      204.0               0.000           NaN       NaN          NaN
# 13734        NaN               0.001           NaN       NaN          NaN
#
#       pitch_count trailing_pitch
# 13738           1            NaN
# 13737           2             FF
# 13736           3             FF
# 13735           4             FF
# 13734           5             FF
#
# [5 rows x 96 columns]

# %%
# sort Senzatela's dataframe and add columns
senzatela_df_sorted = add_data_df(senzatela_df)
senzatela_df_sorted.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 11919         FF  2017-02-25           96.0          -2.76           5.91
# 11918         FF  2017-02-25           96.1          -2.57           6.08
# 11917         FF  2017-02-25           95.7          -2.08           6.36
# 11916         FF  2017-02-25           96.6          -2.49           6.07
# 11915         FF  2017-02-25           94.4          -2.56           5.93
#
#               player_name  batter  pitcher     events    description  ...  \
# 11919  Senzatela, Antonio  571875   622608        NaN           ball  ...
# 11918  Senzatela, Antonio  571875   622608        NaN  called_strike  ...
# 11917  Senzatela, Antonio  571875   622608        NaN           ball  ...
# 11916  Senzatela, Antonio  571875   622608     single  hit_into_play  ...
# 11915  Senzatela, Antonio  630111   622608  field_out  hit_into_play  ...
#
#        post_fld_score  if_fielding_alignment  of_fielding_alignment  \
# 11919               4               Standard               Standard
# 11918               4               Standard               Standard
# 11917               4               Standard               Standard
# 11916               4               Standard               Standard
# 11915               4               Standard               Standard
#
#        spin_axis  delta_home_win_exp delta_run_exp bat_speed swing_length  \
# 11919      216.0               0.000           NaN       NaN          NaN
# 11918      193.0               0.000           NaN       NaN          NaN
# 11917      184.0               0.000           NaN       NaN          NaN
# 11916      198.0               0.044           NaN       NaN          NaN
# 11915      195.0              -0.041           NaN       NaN          NaN
#
#       pitch_count trailing_pitch
# 11919           1            NaN
# 11918           2             FF
# 11917           3             FF
# 11916           4             FF
# 11915           5            NaN
#
# [5 rows x 96 columns]

# %%
# sort Feltner's dataframe and add columns
feltner_df_sorted = add_data_df(feltner_df)
feltner_df_sorted.head()
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 5716         FF  2021-09-05           91.6          -1.82           5.11
# 5715         FF  2021-09-05           93.0          -1.81           5.13
# 5714         SL  2021-09-05           83.9          -1.78           5.15
# 5713         FF  2021-09-05           91.5          -1.90           5.12
# 5712         FF  2021-09-05           92.6          -1.82           5.16
#
#         player_name  batter  pitcher    events    description  ...  \
# 5716  Feltner, Ryan  645277   663372  home_run  hit_into_play  ...
# 5715  Feltner, Ryan  624585   663372       NaN  called_strike  ...
# 5714  Feltner, Ryan  624585   663372       NaN           ball  ...
# 5713  Feltner, Ryan  624585   663372       NaN           ball  ...
# 5712  Feltner, Ryan  624585   663372       NaN           foul  ...
#
#       post_fld_score  if_fielding_alignment  of_fielding_alignment  spin_axis  \
# 5716               0          Infield shift              Strategic      223.0
# 5715               0          Infield shift              Strategic      224.0
# 5714               0          Infield shift              Strategic      110.0
# 5713               0          Infield shift              Strategic      216.0
# 5712               0          Infield shift              Strategic      216.0
#
#       delta_home_win_exp delta_run_exp bat_speed swing_length pitch_count  \
# 5716              -0.101         1.000       NaN          NaN           1
# 5715               0.000        -0.038       NaN          NaN           2
# 5714               0.000         0.027       NaN          NaN           3
# 5713               0.000         0.052       NaN          NaN           4
# 5712               0.000        -0.066       NaN          NaN           5
#
#      trailing_pitch
# 5716            NaN
# 5715            NaN
# 5714             FF
# 5713             SL
# 5712             FF
#
# [5 rows x 96 columns]

# %%
# sort Flexen's dataframe and add columns
flexen_df_sorted = add_data_df(flexen_df)
flexen_df_sorted.head()
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 6665         FF  2017-07-27           93.2          -1.43           6.31
# 6664         FF  2017-07-27           92.5          -1.55           6.33
# 6663         CU  2017-07-27           76.6          -1.36           6.30
# 6662         FF  2017-07-27           92.5          -1.54           6.33
# 6661         FF  2017-07-27           92.5          -1.60           6.33
#
#         player_name  batter  pitcher    events    description  ...  \
# 6665  Flexen, Chris  622534   623167       NaN  called_strike  ...
# 6664  Flexen, Chris  622534   623167       NaN           foul  ...
# 6663  Flexen, Chris  622534   623167  home_run  hit_into_play  ...
# 6662  Flexen, Chris  641319   623167       NaN           ball  ...
# 6661  Flexen, Chris  641319   623167       NaN           ball  ...
#
#       post_fld_score  if_fielding_alignment  of_fielding_alignment  spin_axis  \
# 6665               1               Standard               Standard      224.0
# 6664               1               Standard               Standard      212.0
# 6663               1               Standard               Standard        8.0
# 6662               1               Standard               Standard      224.0
# 6661               1               Standard               Standard      223.0
#
#       delta_home_win_exp delta_run_exp bat_speed swing_length pitch_count  \
# 6665               0.000        -0.037       NaN          NaN           1
# 6664               0.000        -0.056       NaN          NaN           2
# 6663               0.105         1.093       NaN          NaN           3
# 6662               0.000         0.036       NaN          NaN           4
# 6661               0.000         0.065       NaN          NaN           5
#
#      trailing_pitch
# 6665            NaN
# 6664             FF
# 6663             FF
# 6662            NaN
# 6661             FF
#
# [5 rows x 96 columns]

# %%
# combine all individual pitcher dataframes into a single dataframe
pitchers_df = pd.concat([freeland_df_sorted, marquez_df_sorted, senzatela_df_sorted, feltner_df_sorted, flexen_df_sorted], axis=0, ignore_index=True)
pitchers_df
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0             FF  2017-02-28           93.5           3.20           5.68
# 1             FF  2017-02-28           93.5           3.08           5.96
# 2             SL  2017-02-28           92.0           3.27           5.66
# 3             FF  2017-02-28           95.1           3.25           5.64
# 4             SL  2017-02-28           87.8           3.21           5.76
# ...          ...         ...            ...            ...            ...
# 65810         FF  2024-09-26           92.2          -0.29           6.75
# 65811         FF  2024-09-26           91.0          -0.12           6.92
# 65812         CU  2024-09-26           70.7          -0.04           6.97
# 65813         SL  2024-09-26           79.4          -0.16           6.83
# 65814         FC  2024-09-26           87.6          -0.22           6.87
#
#           player_name  batter  pitcher     events      description  ...  \
# 0      Freeland, Kyle  444843   607536        NaN             ball  ...
# 1      Freeland, Kyle  444843   607536        NaN             foul  ...
# 2      Freeland, Kyle  444843   607536        NaN             foul  ...
# 3      Freeland, Kyle  444843   607536        NaN             foul  ...
# 4      Freeland, Kyle  444843   607536  strikeout  swinging_strike  ...
# ...               ...     ...      ...        ...              ...  ...
# 65810   Flexen, Chris  676572   623167     single    hit_into_play  ...
# 65811   Flexen, Chris  592273   623167        NaN             foul  ...
# 65812   Flexen, Chris  592273   623167        NaN    called_strike  ...
# 65813   Flexen, Chris  592273   623167  strikeout  swinging_strike  ...
# 65814   Flexen, Chris  681351   623167     single    hit_into_play  ...
#
#        post_fld_score  if_fielding_alignment  of_fielding_alignment  \
# 0                   0               Standard               Standard
# 1                   0               Standard               Standard
# 2                   0               Standard               Standard
# 3                   0               Standard               Standard
# 4                   0               Standard               Standard
# ...               ...                    ...                    ...
# 65810               7               Standard               Standard
# 65811               7               Standard               Standard
# 65812               7               Standard               Standard
# 65813               7               Standard               Standard
# 65814               7               Standard               Standard
#
#        spin_axis  delta_home_win_exp delta_run_exp bat_speed swing_length  \
# 0          148.0               0.000           NaN       NaN          NaN
# 1          169.0               0.000           NaN       NaN          NaN
# 2          176.0               0.000           NaN       NaN          NaN
# 3          141.0               0.000           NaN       NaN          NaN
# 4          193.0               0.022           NaN       NaN          NaN
# ...          ...                 ...           ...       ...          ...
# 65810      191.0              -0.005         0.365  63.06783      6.09774
# 65811      191.0               0.000        -0.063  73.46046      6.96244
# 65812       20.0               0.000        -0.073       NaN          NaN
# 65813       24.0               0.005        -0.225  25.47238      6.91687
# 65814      141.0              -0.005         0.477  70.73772      7.23126
#
#       pitch_count trailing_pitch
# 0               1            NaN
# 1               2             FF
# 2               3             FF
# 3               4             SL
# 4               5             FF
# ...           ...            ...
# 65810          92             FF
# 65811          93             FF
# 65812          94             FF
# 65813          95             CU
# 65814          96             FF
#
# [65815 rows x 96 columns]

# %% [markdown]
# # Export Master Dataframe

# %%
# export master pitcher dataframe to csv
pitchers_df.to_csv("../data/all_pitcher_data.csv")

# %% [markdown]
# # Quick look at the data

# %%
# look at list of columns in the master dataframe
column_list = pitchers_df.columns.to_list()
column_list
# Out:
# ['pitch_type',
#  'game_date',
#  'release_speed',
#  'release_pos_x',
#  'release_pos_z',
#  'player_name',
#  'batter',
#  'pitcher',
#  'events',
#  'description',
#  'spin_dir',
#  'spin_rate_deprecated',
#  'break_angle_deprecated',
#  'break_length_deprecated',
#  'zone',
#  'des',
#  'game_type',
#  'stand',
#  'p_throws',
#  'home_team',
#  'away_team',
#  'type',
#  'hit_location',
#  'bb_type',
#  'balls',
#  'strikes',
#  'game_year',
#  'pfx_x',
#  'pfx_z',
#  'plate_x',
#  'plate_z',
#  'on_3b',
#  'on_2b',
#  'on_1b',
#  'outs_when_up',
#  'inning',
#  'inning_topbot',
#  'hc_x',
#  'hc_y',
#  'tfs_deprecated',
#  'tfs_zulu_deprecated',
#  'fielder_2',
#  'umpire',
#  'sv_id',
#  'vx0',
#  'vy0',
#  'vz0',
#  'ax',
#  'ay',
#  'az',
#  'sz_top',
#  'sz_bot',
#  'hit_distance_sc',
#  'launch_speed',
#  'launch_angle',
#  'effective_speed',
#  'release_spin_rate',
#  'release_extension',
#  'game_pk',
#  'pitcher.1',
#  'fielder_2.1',
#  'fielder_3',
#  'fielder_4',
#  'fielder_5',
#  'fielder_6',
#  'fielder_7',
#  'fielder_8',
#  'fielder_9',
#  'release_pos_y',
#  'estimated_ba_using_speedangle',
#  'estimated_woba_using_speedangle',
#  'woba_value',
#  'woba_denom',
#  'babip_value',
#  'iso_value',
#  'launch_speed_angle',
#  'at_bat_number',
#  'pitch_number',
#  'pitch_name',
#  'home_score',
#  'away_score',
#  'bat_score',
#  'fld_score',
#  'post_away_score',
#  'post_home_score',
#  'post_bat_score',
#  'post_fld_score',
#  'if_fielding_alignment',
#  'of_fielding_alignment',
#  'spin_axis',
#  'delta_home_win_exp',
#  'delta_run_exp',
#  'bat_speed',
#  'swing_length',
#  'pitch_count',
#  'trailing_pitch']

# %%
# confirm length of list of columns
len(column_list)
# Out:
# 96

# %%
# look at dataframe shape
pitchers_df.shape
# Out:
# (65815, 96)

# %%
# look at overall data info
pitchers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65815 entries, 0 to 65814
# Data columns (total 96 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       64203 non-null  object
#  1   game_date                        65815 non-null  object
#  2   release_speed                    64261 non-null  float64
#  3   release_pos_x                    64261 non-null  float64
#  4   release_pos_z                    64261 non-null  float64
#  5   player_name                      65815 non-null  object
#  6   batter                           65815 non-null  int64
#  7   pitcher                          65815 non-null  int64
#  8   events                           17978 non-null  object
#  9   description                      65815 non-null  object
#  10  spin_dir                         0 non-null      float64
#  11  spin_rate_deprecated             0 non-null      float64
#  12  break_angle_deprecated           0 non-null      float64
#  13  break_length_deprecated          0 non-null      float64
#  14  zone                             64261 non-null  float64
#  15  des                              65815 non-null  object
#  16  game_type                        65815 non-null  object
#  17  stand                            65815 non-null  object
#  18  p_throws                         65815 non-null  object
#  19  home_team                        65815 non-null  object
#  20  away_team                        65815 non-null  object
#  21  type                             65815 non-null  object
#  22  hit_location                     15907 non-null  float64
#  23  bb_type                          13147 non-null  object
#  24  balls                            65815 non-null  int64
#  25  strikes                          65815 non-null  int64
#  26  game_year                        65815 non-null  int64
#  27  pfx_x                            64260 non-null  float64
#  28  pfx_z                            64260 non-null  float64
#  29  plate_x                          64261 non-null  float64
#  30  plate_z                          64261 non-null  float64
#  31  on_3b                            5685 non-null   float64
#  32  on_2b                            11361 non-null  float64
#  33  on_1b                            19616 non-null  float64
#  34  outs_when_up                     65815 non-null  int64
#  35  inning                           65815 non-null  int64
#  36  inning_topbot                    65815 non-null  object
#  37  hc_x                             12983 non-null  float64
#  38  hc_y                             12983 non-null  float64
#  39  tfs_deprecated                   0 non-null      float64
#  40  tfs_zulu_deprecated              0 non-null      float64
#  41  fielder_2                        65815 non-null  int64
#  42  umpire                           0 non-null      float64
#  43  sv_id                            350 non-null    object
#  44  vx0                              64261 non-null  float64
#  45  vy0                              64261 non-null  float64
#  46  vz0                              64261 non-null  float64
#  47  ax                               64261 non-null  float64
#  48  ay                               64261 non-null  float64
#  49  az                               64261 non-null  float64
#  50  sz_top                           64261 non-null  float64
#  51  sz_bot                           64261 non-null  float64
#  52  hit_distance_sc                  20722 non-null  float64
#  53  launch_speed                     20930 non-null  float64
#  54  launch_angle                     20947 non-null  float64
#  55  effective_speed                  64145 non-null  float64
#  56  release_spin_rate                63791 non-null  float64
#  57  release_extension                64170 non-null  float64
#  58  game_pk                          65815 non-null  int64
#  59  pitcher.1                        65815 non-null  int64
#  60  fielder_2.1                      65815 non-null  int64
#  61  fielder_3                        65815 non-null  int64
#  62  fielder_4                        65815 non-null  int64
#  63  fielder_5                        65815 non-null  int64
#  64  fielder_6                        65815 non-null  int64
#  65  fielder_7                        65815 non-null  int64
#  66  fielder_8                        65815 non-null  int64
#  67  fielder_9                        65815 non-null  int64
#  68  release_pos_y                    64261 non-null  float64
#  69  estimated_ba_using_speedangle    12440 non-null  float64
#  70  estimated_woba_using_speedangle  16148 non-null  float64
#  71  woba_value                       17978 non-null  float64
#  72  woba_denom                       16212 non-null  float64
#  73  babip_value                      17978 non-null  float64
#  74  iso_value                        17978 non-null  float64
#  75  launch_speed_angle               12440 non-null  float64
#  76  at_bat_number                    65815 non-null  int64
#  77  pitch_number                     65815 non-null  int64
#  78  pitch_name                       64203 non-null  object
#  79  home_score                       65815 non-null  int64
#  80  away_score                       65815 non-null  int64
#  81  bat_score                        65815 non-null  int64
#  82  fld_score                        65815 non-null  int64
#  83  post_away_score                  65815 non-null  int64
#  84  post_home_score                  65815 non-null  int64
#  85  post_bat_score                   65815 non-null  int64
#  86  post_fld_score                   65815 non-null  int64
#  87  if_fielding_alignment            64141 non-null  object
#  88  of_fielding_alignment            64141 non-null  object
#  89  spin_axis                        64114 non-null  float64
#  90  delta_home_win_exp               65815 non-null  float64
#  91  delta_run_exp                    61289 non-null  float64
#  92  bat_speed                        3300 non-null   float64
#  93  swing_length                     3300 non-null   float64
#  94  pitch_count                      65815 non-null  int64
#  95  trailing_pitch                   61350 non-null  object
# dtypes: float64(48), int64(29), object(19)
# memory usage: 48.2+ MB

# %%
# which columns need to be encoded?
object_columns = pitchers_df.select_dtypes(include=['object'])
object_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65815 entries, 0 to 65814
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pitch_type             64203 non-null  object
#  1   game_date              65815 non-null  object
#  2   player_name            65815 non-null  object
#  3   events                 17978 non-null  object
#  4   description            65815 non-null  object
#  5   des                    65815 non-null  object
#  6   game_type              65815 non-null  object
#  7   stand                  65815 non-null  object
#  8   p_throws               65815 non-null  object
#  9   home_team              65815 non-null  object
#  10  away_team              65815 non-null  object
#  11  type                   65815 non-null  object
#  12  bb_type                13147 non-null  object
#  13  inning_topbot          65815 non-null  object
#  14  sv_id                  350 non-null    object
#  15  pitch_name             64203 non-null  object
#  16  if_fielding_alignment  64141 non-null  object
#  17  of_fielding_alignment  64141 non-null  object
#  18  trailing_pitch         61350 non-null  object
# dtypes: object(19)
# memory usage: 9.5+ MB

# %%
# which columns are completely empty (null values)?
null_columns = pitchers_df.columns[pitchers_df.isnull().all()]
pitchers_df[null_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65815 entries, 0 to 65814
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   spin_dir                 0 non-null      float64
#  1   spin_rate_deprecated     0 non-null      float64
#  2   break_angle_deprecated   0 non-null      float64
#  3   break_length_deprecated  0 non-null      float64
#  4   tfs_deprecated           0 non-null      float64
#  5   tfs_zulu_deprecated      0 non-null      float64
#  6   umpire                   0 non-null      float64
# dtypes: float64(7)
# memory usage: 3.5 MB

# %%
# which columns have some null values?
partial_columns = pitchers_df.columns[pitchers_df.isnull().any() &
                                      ~pitchers_df.isnull().all()]
pitchers_df[partial_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65815 entries, 0 to 65814
# Data columns (total 48 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       64203 non-null  object
#  1   release_speed                    64261 non-null  float64
#  2   release_pos_x                    64261 non-null  float64
#  3   release_pos_z                    64261 non-null  float64
#  4   events                           17978 non-null  object
#  5   zone                             64261 non-null  float64
#  6   hit_location                     15907 non-null  float64
#  7   bb_type                          13147 non-null  object
#  8   pfx_x                            64260 non-null  float64
#  9   pfx_z                            64260 non-null  float64
#  10  plate_x                          64261 non-null  float64
#  11  plate_z                          64261 non-null  float64
#  12  on_3b                            5685 non-null   float64
#  13  on_2b                            11361 non-null  float64
#  14  on_1b                            19616 non-null  float64
#  15  hc_x                             12983 non-null  float64
#  16  hc_y                             12983 non-null  float64
#  17  sv_id                            350 non-null    object
#  18  vx0                              64261 non-null  float64
#  19  vy0                              64261 non-null  float64
#  20  vz0                              64261 non-null  float64
#  21  ax                               64261 non-null  float64
#  22  ay                               64261 non-null  float64
#  23  az                               64261 non-null  float64
#  24  sz_top                           64261 non-null  float64
#  25  sz_bot                           64261 non-null  float64
#  26  hit_distance_sc                  20722 non-null  float64
#  27  launch_speed                     20930 non-null  float64
#  28  launch_angle                     20947 non-null  float64
#  29  effective_speed                  64145 non-null  float64
#  30  release_spin_rate                63791 non-null  float64
#  31  release_extension                64170 non-null  float64
#  32  release_pos_y                    64261 non-null  float64
#  33  estimated_ba_using_speedangle    12440 non-null  float64
#  34  estimated_woba_using_speedangle  16148 non-null  float64
#  35  woba_value                       17978 non-null  float64
#  36  woba_denom                       16212 non-null  float64
#  37  babip_value                      17978 non-null  float64
#  38  iso_value                        17978 non-null  float64
#  39  launch_speed_angle               12440 non-null  float64
#  40  pitch_name                       64203 non-null  object
#  41  if_fielding_alignment            64141 non-null  object
#  42  of_fielding_alignment            64141 non-null  object
#  43  spin_axis                        64114 non-null  float64
#  44  delta_run_exp                    61289 non-null  float64
#  45  bat_speed                        3300 non-null   float64
#  46  swing_length                     3300 non-null   float64
#  47  trailing_pitch                   61350 non-null  object
# dtypes: float64(40), object(8)
# memory usage: 24.1+ MB

# %% [markdown]
# # Data cleanup required:
# 0. Drop any columns that are not useful or may cause data leakage ***(TBD)***
# 1. Encode data for all object columns to remain ***(18 total)***
# 2. Drop all columns that are 100% null values ***(6 total)***
# 3. Determine how to handle null values in columns that are partially null ***(47 columns total)***

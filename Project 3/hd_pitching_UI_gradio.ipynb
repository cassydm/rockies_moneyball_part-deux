# %% [markdown]
# # Integrate app into UI interface: Gradio
#
# - **input fields**:
#     - text box for user to describe current game information
#         - optional: voice-to-text capability
#     - optional: dedicated input fields for current game information (pitcher name, batter name, who is on base, fielding alignment, etc)
# - **output fields**:
#     - LLM Chat with history
#     - optional: toggle on/off history visibility

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\dixon\anaconda3\lib\site-packages (5.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.115.3)
# Requirement already satisfied: ffmpy in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.4.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.4.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.26.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.7.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.41.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.32.0)
# Requirement already satisfied: fsspec in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (2023.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dixon\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: colorama in c:\users\dixon\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dixon\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dixon\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dixon\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.0.7)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dixon\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import all dependencies and libraries
from dotenv import load_dotenv
import os
from langchain import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
# from transformers import pipeline
import gradio as gr


# Load environment variables.
load_dotenv()
# Set the model name for our LLMs.
GEMINI_MODEL = "gemini-1.5-flash"
# Store the API key in a variable.
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")


# instatiate the LLM
llm = ChatGoogleGenerativeAI(google_api_key=GEMINI_API_KEY, model=GEMINI_MODEL, temperature=0.5)


# create a template for the chatbot personality
template = """
You are a baseball coach. Answer only questions that would pertaining to baseball.
If the human asks questions not related to baseball, remind them that your job is to help
them learn answer baseball questions, and ask them for a question on that topic. If they ask a question which
there is not enough information to answer, tell them you don't know and don't make up an 
answer.

Current conversation:
{history}
Human: {input}
AI Assistant:"""

prompt = PromptTemplate(
    input_variables=["history", "input"],
    template=template
)


# create conversation chain with memory
memory = ConversationBufferMemory(return_messages=True)
conversation = ConversationChain(llm=llm, memory=memory, prompt=prompt,verbose=True)

# %%
# function for quick tests:

def placeholder_fn(query, history):
    # add user's message to conversation history
    history.append(("User", query))
    # get response from AI
    result = conversation.predict(input=query)
    # add AI response to conversation history
    history.append(("AI", result))
    # format conversation history for display
    formatted_history = "\n".join([f"{sender}: {msg}" for sender, msg in history])

    return formatted_history, history

# %% [markdown]
# ## stretch goal: voice to text functionality
# add this functionality after core functionality is complete.

# %% [markdown]
# ## Integrate LLM/Transformer function(s) into Gradio

# %%
# gradio app

chat_app = gr.Interface(
    fn = placeholder_fn, 
    inputs = [
        # gr.Audio(source="microphone", type="filepath", label="Speak your message (optional)"),
        gr.Textbox(lines = 2, label = "Or type your message here"),
        gr.State([])
    ],
    outputs = [
        gr.Textbox(lines = 10, label="Coach AI response:", show_copy_button=True),
        gr.State()
    ],
    title="Coach AI",
    description="Chat with an AI using your voice or by typing. The AI remembers your conversation history."
)

# %%
pip install SpeechRecognition gradio pydub
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\dixon\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: gradio in c:\users\dixon\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: pydub in c:\users\dixon\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\dixon\anaconda3\lib\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\dixon\anaconda3\lib\site-packages (from SpeechRecognition) (4.12.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.115.3)
# Requirement already satisfied: ffmpy in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.4.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.4.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.26.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.7.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.41.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.32.0)
# Requirement already satisfied: fsspec in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (2023.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dixon\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dixon\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dixon\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: click>=8.0.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: colorama in c:\users\dixon\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dixon\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dixon\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Installs  three(3) python packages (gradio, SpeechRecognition, and Pyaudio)
pip install gradio SpeechRecognition pyaudio
# Out:
# Requirement already satisfied: gradio in c:\users\dixon\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: SpeechRecognition in c:\users\dixon\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: pyaudio in c:\users\dixon\anaconda3\lib\site-packages (0.2.14)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.115.3)
# Requirement already satisfied: ffmpy in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.4.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.4.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.26.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.7.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.41.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio) (0.32.0)
# Requirement already satisfied: fsspec in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (2023.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\dixon\anaconda3\lib\site-packages (from gradio-client==1.4.2->gradio) (12.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\dixon\anaconda3\lib\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dixon\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\dixon\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dixon\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dixon\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dixon\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\dixon\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dixon\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dixon\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: click>=8.0.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dixon\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: colorama in c:\users\dixon\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dixon\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dixon\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dixon\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Defines function recognize speech and allows user to user their voice into chat_app using gradio
import gradio as gr
import speech_recognition as sr

def recognize_speech(audio):
    # Initialize recognizer
    recognizer = sr.Recognizer()
    
    # Load the audio file
    with sr.AudioFile(audio) as source:
        audio_data = recognizer.record(source)
    
    # Recognize speech using Google Web Speech API
    try:
        text = recognizer.recognize_google(audio_data)
        return text
    except sr.UnknownValueError:
        return "Could not understand audio"
    except sr.RequestError as e:
        return f"Could not request results; {e}"

chat_app = gr.Interface(
    fn=recognize_speech,
    inputs=gr.Audio(type="filepath"),
    outputs="text",
    title="Speech to Text Converter",
    description="Record your speech to convert it to text.",
)

chat_app.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://ea7a1e654fc514ba41.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ea7a1e654fc514ba41.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
gr.themes.builder()
# Out:
# c:\Users\dixon\anaconda3\Lib\site-packages\gradio\components\chatbot.py:223: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 406, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 187, in __call__
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 790, in __call__
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 348, in __call__
#     await self._handle_simple(send, send_header_only)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 377, in _handle_simple
#     await send({"type": "http.response.body", "body": chunk, "more_body": more_body})
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 162, in _send
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 510, in send
#     output = self.conn.send(event=h11.EndOfMessage())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 512, in send
#     data_list = self.send_with_data_passthrough(event)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 545, in send_with_data_passthrough
#     writer(event, data_list.append)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 67, in __call__
#     self.send_eom(event.headers, write)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 96, in send_eom
#     raise LocalProtocolError("Too little data for declared Content-Length")
# h11._util.LocalProtocolError: Too little data for declared Content-Length
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 406, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 187, in __call__
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 790, in __call__
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 348, in __call__
#     await self._handle_simple(send, send_header_only)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 377, in _handle_simple
#     await send({"type": "http.response.body", "body": chunk, "more_body": more_body})
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 162, in _send
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 510, in send
#     output = self.conn.send(event=h11.EndOfMessage())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 512, in send
#     data_list = self.send_with_data_passthrough(event)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 545, in send_with_data_passthrough
#     writer(event, data_list.append)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 67, in __call__
#     self.send_eom(event.headers, write)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 96, in send_eom
#     raise LocalProtocolError("Too little data for declared Content-Length")
# h11._util.LocalProtocolError: Too little data for declared Content-Length
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 406, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 187, in __call__
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 790, in __call__
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 348, in __call__
#     await self._handle_simple(send, send_header_only)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\responses.py", line 377, in _handle_simple
#     await send({"type": "http.response.body", "body": chunk, "more_body": more_body})
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\starlette\middleware\errors.py", line 162, in _send
#     await send(message)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 510, in send
#     output = self.conn.send(event=h11.EndOfMessage())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 512, in send
#     data_list = self.send_with_data_passthrough(event)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_connection.py", line 545, in send_with_data_passthrough
#     writer(event, data_list.append)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 67, in __call__
#     self.send_eom(event.headers, write)
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\h11\_writers.py", line 96, in send_eom
#     raise LocalProtocolError("Too little data for declared Content-Length")
# h11._util.LocalProtocolError: Too little data for declared Content-Length
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\queueing.py", line 624, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 323, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 2018, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 1567, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\utils.py", line 846, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dixon\AppData\Local\Temp\ipykernel_4148\875963302.py", line 10, in transcribe_audio
#     audio_data = sr.AudioData(audio.get_wav_data(), sample_rate=16000, sample_width=2)
#                               ^^^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'get_wav_data'
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\queueing.py", line 624, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 323, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 2018, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 1567, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\utils.py", line 846, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dixon\AppData\Local\Temp\ipykernel_4148\875963302.py", line 10, in transcribe_audio
#     audio_data = sr.AudioData(audio.get_wav_data(), sample_rate=16000, sample_width=2)
#                               ^^^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'get_wav_data'
# Traceback (most recent call last):
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\queueing.py", line 624, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\route_utils.py", line 323, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 2018, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\blocks.py", line 1567, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 2134, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\dixon\anaconda3\Lib\site-packages\gradio\utils.py", line 846, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dixon\AppData\Local\Temp\ipykernel_4148\875963302.py", line 10, in transcribe_audio
#     audio_data = sr.AudioData(audio.get_wav_data(), sample_rate=16000, sample_width=2)
#                               ^^^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'get_wav_data'
